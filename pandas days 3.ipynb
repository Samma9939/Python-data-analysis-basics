# %%
people = {
    "first":["Samma","soni","saniya"],
    "last":["Khatoon","begam","firdous"],
    "email":["sammakhatoon677@gmail.com","sonibegam23@gmail.com", "saniyafirdous456@gmail.com"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                       email
# 0   Samma  Khatoon   sammakhatoon677@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                              first     last
# email
# sammakhatoon677@gmail.com    Samma  Khatoon
# sonibegam23@gmail.com         soni    begam
# saniyafirdous456@gmail.com  saniya  firdous

# %%
df.index
# Out:
# Index(['sammakhatoon677@gmail.com', 'sonibegam23@gmail.com',
#        'saniyafirdous456@gmail.com'],
#       dtype='object', name='email')

# %%
df.loc['sammakhatoon677@gmail.com','last']
# Out:
# 'Khatoon'

# %%
df.iloc[0]
# Out:
# first      Samma
# last     Khatoon
# Name: sammakhatoon677@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                         email   first     last
# 0   sammakhatoon677@gmail.com   Samma  Khatoon
# 1       sonibegam23@gmail.com    soni    begam
# 2  saniyafirdous456@gmail.com  saniya  firdous
