# %%
people = {
    "first":["samma","soni","saniya"],
    "last":["khatoon","begam","firdous"],
    "email":["sammakhatoon23@gmail.com","sonibegam23@gmail.com", "saniyafirdous456@gmail.com"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                       email
# 0   samma  khatoon    sammakhatoon23@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df['first']+' '+df['last']
# Out:
# 0     samma khatoon
# 1        soni begam
# 2    saniya firdous
# dtype: object

# %%
df['full_name']=df['first']+' '+df['last']

# %%
df
# Out:
#     first     last                       email       full_name
# 0   samma  khatoon    sammakhatoon23@gmail.com   samma khatoon
# 1    soni    begam       sonibegam23@gmail.com      soni begam
# 2  saniya  firdous  saniyafirdous456@gmail.com  saniya firdous

# %%
df.drop(columns=['first','last'],inplace=True)

# %%
df
# Out:
#                         email       full_name
# 0    sammakhatoon23@gmail.com   samma khatoon
# 1       sonibegam23@gmail.com      soni begam
# 2  saniyafirdous456@gmail.com  saniya firdous

# %%
df['full_name'].str.split(' ')
# Out:
# 0     [samma, khatoon]
# 1        [soni, begam]
# 2    [saniya, firdous]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ',expand=True)
# Out:
#         0        1
# 0   samma  khatoon
# 1    soni    begam
# 2  saniya  firdous

# %%
df[['first','last']]=df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 1       sonibegam23@gmail.com      soni begam    soni    begam
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous

# %%
df=pd.concat([df,pd.DataFrame([{'first': 'parvej'}])],ignore_index=True)

# %%
df
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 1       sonibegam23@gmail.com      soni begam    soni    begam
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous
# 3                         NaN             NaN  parvej      NaN

# %%
people = {
    "first":["alfiya","asia"],
    "last":["parveen","ali"],
    "email":["alfiyaparveen45@gmail.com","asiaali678@gmail.com"]
}
df2=pd.DataFrame(people)

# %%
df2
# Out:
#     first     last                      email
# 0  alfiya  parveen  alfiyaparveen45@gmail.com
# 1    asia      ali       asiaali678@gmail.com

# %%
df=pd.concat([df,df2],ignore_index=True,sort=False)

# %%
df
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 1       sonibegam23@gmail.com      soni begam    soni    begam
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous
# 3                         NaN             NaN  parvej      NaN
# 4   alfiyaparveen45@gmail.com             NaN  alfiya  parveen
# 5        asiaali678@gmail.com             NaN    asia      ali

# %%
df.drop(index=5)
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 1       sonibegam23@gmail.com      soni begam    soni    begam
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous
# 3                         NaN             NaN  parvej      NaN
# 4   alfiyaparveen45@gmail.com             NaN  alfiya  parveen

# %%
filt=df['last']=='begam'
df.drop(index=df[filt].index)
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous
# 3                         NaN             NaN  parvej      NaN
# 4   alfiyaparveen45@gmail.com             NaN  alfiya  parveen
# 5        asiaali678@gmail.com             NaN    asia      ali

# %%
df.drop(index=4)
# Out:
#                         email       full_name   first     last
# 0    sammakhatoon23@gmail.com   samma khatoon   samma  khatoon
# 1       sonibegam23@gmail.com      soni begam    soni    begam
# 2  saniyafirdous456@gmail.com  saniya firdous  saniya  firdous
# 3                         NaN             NaN  parvej      NaN
# 5        asiaali678@gmail.com             NaN    asia      ali
