# %%
people = {
    "first":["Samma","soni","saniya","adam"],
    "last":["ali","khatoon","firdous","firdous"],
    "email":["sammakhatoon677@gmail.com","sonibegam23@gmail.com", "saniyafirdous456@gmail.com","adamfirdous@gmail.com"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                       email
# 0   Samma      ali   sammakhatoon677@gmail.com
# 1    soni  khatoon       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com
# 3    adam  firdous       adamfirdous@gmail.com

# %%
df.sort_values(by='last')
# Out:
#     first     last                       email
# 0   Samma      ali   sammakhatoon677@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com
# 3    adam  firdous       adamfirdous@gmail.com
# 1    soni  khatoon       sonibegam23@gmail.com

# %%
df.sort_values(by='last',ascending=False)
# Out:
#     first     last                       email
# 1    soni  khatoon       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com
# 3    adam  firdous       adamfirdous@gmail.com
# 0   Samma      ali   sammakhatoon677@gmail.com

# %%
df.sort_values(by=['last','first'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#     first     last                       email
# 1    soni  khatoon       sonibegam23@gmail.com
# 3    adam  firdous       adamfirdous@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com
# 0   Samma      ali   sammakhatoon677@gmail.com

# %%
df.sort_index()
# Out:
#     first     last                       email
# 0   Samma      ali   sammakhatoon677@gmail.com
# 1    soni  khatoon       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com
# 3    adam  firdous       adamfirdous@gmail.com

# %%
df['last'].sort_values()
# Out:
# 0        ali
# 3    firdous
# 2    firdous
# 1    khatoon
# Name: last, dtype: object
