# %%
people= {
    "first":"Samma",
    "last":"Khatoon",
    "email":"sammakhatoon677@gmail.com"
}

# %%
people = {
    "first":["Samma"],
    "last":["Khatoon"],
    "email":["sammakhatoon677@gmail.com"]
}

# %%
people = {
    "first":["Samma","soni","saniya"],
    "last":["Khatoon","begam","firdous"],
    "email":["sammakhatoon677@gmail.com","sonibegam23@gmail.com", "saniyafirdous456@gmail.com"]
}

# %%
people['email']
# Out:
# ['sammakhatoon677@gmail.com',
#  'sonibegam23@gmail.com',
#  'saniyafirdous456@gmail.com']

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                       email
# 0   Samma  Khatoon   sammakhatoon677@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df['email']
# Out:
# 0     sammakhatoon677@gmail.com
# 1         sonibegam23@gmail.com
# 2    saniyafirdous456@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0     sammakhatoon677@gmail.com
# 1         sonibegam23@gmail.com
# 2    saniyafirdous456@gmail.com
# Name: email, dtype: object

# %%
df[['last','email']]
# Out:
#       last                       email
# 0  Khatoon   sammakhatoon677@gmail.com
# 1    begam       sonibegam23@gmail.com
# 2  firdous  saniyafirdous456@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                        Samma
# last                       Khatoon
# email    sammakhatoon677@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0, 1]]
# Out:
#    first     last                      email
# 0  Samma  Khatoon  sammakhatoon677@gmail.com
# 1   soni    begam      sonibegam23@gmail.com

# %%
df
# Out:
#     first     last                       email
# 0   Samma  Khatoon   sammakhatoon677@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df.loc[0]
# Out:
# first                        Samma
# last                       Khatoon
# email    sammakhatoon677@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#    first     last                      email
# 0  Samma  Khatoon  sammakhatoon677@gmail.com
# 1   soni    begam      sonibegam23@gmail.com

# %%
df.loc[[0, 1], ['email','last']]
# Out:
#                        email     last
# 0  sammakhatoon677@gmail.com  Khatoon
# 1      sonibegam23@gmail.com    begam
