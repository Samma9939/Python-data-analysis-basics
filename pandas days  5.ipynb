# %%
import pandas as pd

# %%
people = {
    "first":["samma","soni","saniya"],
    "last":["begam","begam","firdous"],
    "email":["sammabegam23@gmail.com","sonibegam23@gmail.com", "saniyafirdous456@gmail.com"]
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                       email
# 0   samma    begam      sammabegam23@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns=['first_name','last_name','email']

# %%
df
# Out:
#   first_name last_name                       email
# 0      samma     begam      sammabegam23@gmail.com
# 1       soni     begam       sonibegam23@gmail.com
# 2     saniya   firdous  saniyafirdous456@gmail.com

# %%
df.columns=[x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                       EMAIL
# 0      samma     begam      sammabegam23@gmail.com
# 1       soni     begam       sonibegam23@gmail.com
# 2     saniya   firdous  saniyafirdous456@gmail.com

# %%
df.columns=df.columns.str.replace('_', ' ')
df
# Out:
#   FIRST NAME LAST NAME                       EMAIL
# 0      samma     begam      sammabegam23@gmail.com
# 1       soni     begam       sonibegam23@gmail.com
# 2     saniya   firdous  saniyafirdous456@gmail.com

# %%
df.columns=[x.lower() for x in df.columns]
df
# Out:
#   first name last name                       email
# 0      samma     begam      sammabegam23@gmail.com
# 1       soni     begam       sonibegam23@gmail.com
# 2     saniya   firdous  saniyafirdous456@gmail.com

# %%
df.columns=df.columns.str.replace(' ', '_')
df
# Out:
#   first_name last_name                       email
# 0      samma     begam      sammabegam23@gmail.com
# 1       soni     begam       sonibegam23@gmail.com
# 2     saniya   firdous  saniyafirdous456@gmail.com

# %%
df.rename(columns={'first_name':'first','last_name':'last'},inplace=True)

# %%
df
# Out:
#     first     last                       email
# 0   samma    begam      sammabegam23@gmail.com
# 1    soni    begam       sonibegam23@gmail.com
# 2  saniya  firdous  saniyafirdous456@gmail.com

# %%
df.loc[2]
# Out:
# first                        saniya
# last                        firdous
# email    saniyafirdous456@gmail.com
# Name: 2, dtype: object

# %%
df.loc[2]=['sageena','khatoon','sageenak34@gmail.com']

# %%
df
# Out:
#      first     last                   email
# 0    samma    begam  sammabegam23@gmail.com
# 1     soni    begam   sonibegam23@gmail.com
# 2  sageena  khatoon    sageenak34@gmail.com

# %%
df.loc[2,['last','email']]
# Out:
# last                  khatoon
# email    sageenak34@gmail.com
# Name: 2, dtype: object

# %%
df.loc[2,['last','email']]=['firdous','sageenafirdous456@gmail.com']

# %%
df
# Out:
#      first     last                        email
# 0    samma    begam       sammabegam23@gmail.com
# 1     soni    begam        sonibegam23@gmail.com
# 2  sageena  firdous  sageenafirdous456@gmail.com

# %%
df.loc[2,'last']='khatoon'

# %%
df
# Out:
#      first     last                        email
# 0    samma    begam       sammabegam23@gmail.com
# 1     soni    begam        sonibegam23@gmail.com
# 2  sageena  khatoon  sageenafirdous456@gmail.com

# %%
df.at[2,'last']='begam'

# %%
df
# Out:
#      first   last                        email
# 0    samma  begam       sammabegam23@gmail.com
# 1     soni  begam        sonibegam23@gmail.com
# 2  sageena  begam  sageenafirdous456@gmail.com

# %%
filt=(df['email']=='sageenafirdous456@gmail.com')
df[filt]
# Out:
#      first   last                        email
# 2  sageena  begam  sageenafirdous456@gmail.com

# %%
filt=(df['email']=='sageenafirdous456@gmail.com')
df.loc[filt,'last']='raja'

# %%
df
# Out:
#      first   last                        email
# 0    samma  begam       sammabegam23@gmail.com
# 1     soni  begam        sonibegam23@gmail.com
# 2  sageena   raja  sageenafirdous456@gmail.com

# %%
df['email'].str.lower()
# Out:
# 0         sammabegam23@gmail.com
# 1          sonibegam23@gmail.com
# 2    sageenafirdous456@gmail.com
# Name: email, dtype: object

# %%
df['email']=df['email'].str.lower()

# %%
df
# Out:
#      first   last                        email
# 0    samma  begam       sammabegam23@gmail.com
# 1     soni  begam        sonibegam23@gmail.com
# 2  sageena   raja  sageenafirdous456@gmail.com

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    21
# 2    27
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0         SAMMABEGAM23@GMAIL.COM
# 1          SONIBEGAM23@GMAIL.COM
# 2    SAGEENAFIRDOUS456@GMAIL.COM
# Name: email, dtype: object

# %%
df['email']=df['email'].apply(update_email)

# %%
df
# Out:
#      first   last                        email
# 0    samma  begam       SAMMABEGAM23@GMAIL.COM
# 1     soni  begam        SONIBEGAM23@GMAIL.COM
# 2  sageena   raja  SAGEENAFIRDOUS456@GMAIL.COM

# %%
df['email']=df['email'].apply(lambda x:x.lower())

# %%
df
# Out:
#      first   last                        email
# 0    samma  begam       sammabegam23@gmail.com
# 1     soni  begam        sonibegam23@gmail.com
# 2  sageena   raja  sageenafirdous456@gmail.com

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    21
# 2    27
# Name: email, dtype: int64

# %%
df.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(pd.Series.min)
# Out:
# first                        sageena
# last                           begam
# email    sageenafirdous456@gmail.com
# dtype: object

# %%
df.apply(lambda x:x.min())
# Out:
# first                        sageena
# last                           begam
# email    sageenafirdous456@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
# C:\Users\samma\AppData\Local\Temp\ipykernel_10336\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last  email
# 0      5     5     22
# 1      4     5     21
# 2      7     4     27

# %%
df.applymap(str.lower)
# Out:
# C:\Users\samma\AppData\Local\Temp\ipykernel_10336\357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#      first   last                        email
# 0    samma  begam       sammabegam23@gmail.com
# 1     soni  begam        sonibegam23@gmail.com
# 2  sageena   raja  sageenafirdous456@gmail.com

# %%
df['first'].map({'samma':'glden','soni':'saniya'})
# Out:
# 0     glden
# 1    saniya
# 2       NaN
# Name: first, dtype: object

# %%
df['first']=df['first'].replace({'samma':'glden','soni':'saniya'})

# %%
df
# Out:
#      first   last                        email
# 0    glden  begam       sammabegam23@gmail.com
# 1   saniya  begam        sonibegam23@gmail.com
# 2  sageena   raja  sageenafirdous456@gmail.com
